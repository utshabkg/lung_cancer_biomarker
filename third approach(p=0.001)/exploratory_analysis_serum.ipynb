# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
serum = pd.read_csv('G:/Research/SM Sir/LungCancer_Biomarker/dataset/serum_processed.csv')
serum = serum.drop(['Unnamed: 0'], axis=1)
serum
# Out:
#     1_5-anhydroglucitol  1-monostearin  2_3-dihydroxybutanoic acid NIST  \
# 0                  9582            279                               82
# 1                 28847            161                               78
# 2                 13627            162                               53
# 3                 20758           6671                               93
# 4                 15692            108                               98
# ..                  ...            ...                              ...
# 77                25194            108                              106
# 78                23525             83                              140
# 79                25154            418                               90
# 80                12397            110                              104
# 81                18350             73                              179
#
#     2_4-diaminobutyric acid  2-deoxyerythritol  2-deoxytetronic acid  \
# 0                        61                357                   122
# 1                        84                205                   258
# 2                       133                139                   159
# 3                        78                335                   225
# 4                        69                250                   120
# ..                      ...                ...                   ...
# 77                       32                127                   185
# 78                      261                167                   181
# 79                      307                284                   100
# 80                       56                342                   186
# 81                       86                279                   197
#
#     2-hydroxybutanoic acid  2-hydroxyglutaric acid  2-hydroxyhippuric acid  \
# 0                    24944                      56                      32
# 1                    10680                     104                      49
# 2                    27201                     160                      80
# 3                    32347                     242                      59
# 4                    18357                      60                      25
# ..                     ...                     ...                     ...
# 77                   23821                      53                     103
# 78                   12396                      65                      39
# 79                   11788                     124                     106
# 80                   15214                      47                     129
# 81                   16085                      60                     198
#
#     2-hydroxyvaleric acid  ...  tryptophan  tyrosine  UDP-glucuronic acid  \
# 0                     966  ...       34239     54924                   43
# 1                    1076  ...       20080     37597                  203
# 2                    1117  ...       29191     28707                  211
# 3                     304  ...       16637     27873                   71
# 4                    1220  ...       29820     30132                  200
# ..                    ...  ...         ...       ...                  ...
# 77                   1334  ...       34521     35970                   92
# 78                   1408  ...       28112     28014                  104
# 79                    997  ...       39591     37287                  166
# 80                    924  ...       29273     23742                 1903
# 81                    899  ...       23651     32068                   69
#
#       urea  uric acid  uridine  valine  xylitol  xylose    Class
# 0   226295      11606       68  153849      194     811  disease
# 1    96226      10188       71  110735      294     910  disease
# 2   155596      16617      123   95509      253     804  disease
# 3   191671      15214       84   96219      157     806  disease
# 4   333019      20281       62  159853      188    1226  disease
# ..     ...        ...      ...     ...      ...     ...      ...
# 77  262448      18757       54  108092      180     748  control
# 78  310051      26134       50  134469      211     651  control
# 79  295930      21733       69   82547      457     749  control
# 80  276190      17275       68  112921     1256     526  control
# 81  152978      24358       61  134869      144    1823  control
#
# [82 rows x 159 columns]

# %%
serum.dtypes
# Out:
# 1_5-anhydroglucitol                 int64
# 1-monostearin                       int64
# 2_3-dihydroxybutanoic acid NIST     int64
# 2_4-diaminobutyric acid             int64
# 2-deoxyerythritol                   int64
#                                     ...
# uridine                             int64
# valine                              int64
# xylitol                             int64
# xylose                              int64
# Class                              object
# Length: 159, dtype: object

# %% [markdown]
# # Deal with NaN Values:

# %%
serum.isnull().any()
# Out:
# 1_5-anhydroglucitol                False
# 1-monostearin                      False
# 2_3-dihydroxybutanoic acid NIST    False
# 2_4-diaminobutyric acid            False
# 2-deoxyerythritol                  False
#                                    ...
# uridine                            False
# valine                             False
# xylitol                            False
# xylose                             False
# Class                              False
# Length: 159, dtype: bool

# %%
serum.corr()
# Out:
#                                  1_5-anhydroglucitol  1-monostearin  \
# 1_5-anhydroglucitol                         1.000000       0.007798
# 1-monostearin                               0.007798       1.000000
# 2_3-dihydroxybutanoic acid NIST            -0.012825       0.012752
# 2_4-diaminobutyric acid                     0.122006      -0.106090
# 2-deoxyerythritol                           0.019168      -0.099975
# ...                                              ...            ...
# uric acid                                   0.245431      -0.048083
# uridine                                     0.267536      -0.078234
# valine                                     -0.143464      -0.097429
# xylitol                                     0.286272      -0.066704
# xylose                                     -0.086360      -0.043400
#
#                                  2_3-dihydroxybutanoic acid NIST  \
# 1_5-anhydroglucitol                                    -0.012825
# 1-monostearin                                           0.012752
# 2_3-dihydroxybutanoic acid NIST                         1.000000
# 2_4-diaminobutyric acid                                 0.128522
# 2-deoxyerythritol                                       0.240383
# ...                                                          ...
# uric acid                                               0.128645
# uridine                                                 0.039247
# valine                                                  0.024272
# xylitol                                                -0.067505
# xylose                                                  0.348359
#
#                                  2_4-diaminobutyric acid  2-deoxyerythritol  \
# 1_5-anhydroglucitol                             0.122006           0.019168
# 1-monostearin                                  -0.106090          -0.099975
# 2_3-dihydroxybutanoic acid NIST                 0.128522           0.240383
# 2_4-diaminobutyric acid                         1.000000           0.101274
# 2-deoxyerythritol                               0.101274           1.000000
# ...                                                  ...                ...
# uric acid                                       0.100445           0.084623
# uridine                                        -0.103013           0.026157
# valine                                         -0.104377          -0.147918
# xylitol                                         0.124099          -0.074666
# xylose                                          0.296243           0.328630
#
#                                  2-deoxytetronic acid  2-hydroxybutanoic acid  \
# 1_5-anhydroglucitol                          0.019649               -0.122953
# 1-monostearin                                0.123557                0.154190
# 2_3-dihydroxybutanoic acid NIST              0.291421               -0.061552
# 2_4-diaminobutyric acid                      0.009993               -0.083307
# 2-deoxyerythritol                            0.152680               -0.359583
# ...                                               ...                     ...
# uric acid                                    0.054894               -0.176395
# uridine                                      0.040491                0.002701
# valine                                      -0.456963                0.112178
# xylitol                                     -0.016564               -0.156837
# xylose                                       0.360736               -0.261606
#
#                                  2-hydroxyglutaric acid  \
# 1_5-anhydroglucitol                           -0.006852
# 1-monostearin                                 -0.086160
# 2_3-dihydroxybutanoic acid NIST               -0.152277
# 2_4-diaminobutyric acid                       -0.081897
# 2-deoxyerythritol                              0.012092
# ...                                                 ...
# uric acid                                      0.187119
# uridine                                        0.180434
# valine                                        -0.310998
# xylitol                                        0.036496
# xylose                                        -0.024578
#
#                                  2-hydroxyhippuric acid  \
# 1_5-anhydroglucitol                           -0.199060
# 1-monostearin                                 -0.026154
# 2_3-dihydroxybutanoic acid NIST               -0.063881
# 2_4-diaminobutyric acid                       -0.000489
# 2-deoxyerythritol                              0.107085
# ...                                                 ...
# uric acid                                      0.009909
# uridine                                       -0.097886
# valine                                        -0.109504
# xylitol                                       -0.085610
# xylose                                        -0.091183
#
#                                  2-hydroxyvaleric acid  ...  \
# 1_5-anhydroglucitol                          -0.167857  ...
# 1-monostearin                                -0.148145  ...
# 2_3-dihydroxybutanoic acid NIST               0.152715  ...
# 2_4-diaminobutyric acid                      -0.066843  ...
# 2-deoxyerythritol                             0.000166  ...
# ...                                                ...  ...
# uric acid                                     0.079156  ...
# uridine                                      -0.034188  ...
# valine                                        0.077695  ...
# xylitol                                      -0.112719  ...
# xylose                                        0.232430  ...
#
#                                  trans-4-hydroxyproline  tryptophan  tyrosine  \
# 1_5-anhydroglucitol                           -0.045141    0.142258  0.026889
# 1-monostearin                                 -0.085115   -0.033920 -0.060940
# 2_3-dihydroxybutanoic acid NIST               -0.003712   -0.122123 -0.095652
# 2_4-diaminobutyric acid                        0.049420   -0.021487 -0.055918
# 2-deoxyerythritol                              0.131297    0.082826  0.192573
# ...                                                 ...         ...       ...
# uric acid                                      0.236742    0.091698 -0.207577
# uridine                                       -0.232771    0.019746 -0.107049
# valine                                         0.039473    0.362370  0.343479
# xylitol                                       -0.065717   -0.028156 -0.058608
# xylose                                         0.130314   -0.216527 -0.124610
#
#                                  UDP-glucuronic acid      urea  uric acid  \
# 1_5-anhydroglucitol                        -0.019308 -0.258613   0.245431
# 1-monostearin                              -0.058282 -0.023995  -0.048083
# 2_3-dihydroxybutanoic acid NIST            -0.042704  0.280825   0.128645
# 2_4-diaminobutyric acid                     0.000057  0.124461   0.100445
# 2-deoxyerythritol                          -0.039818  0.051053   0.084623
# ...                                              ...       ...        ...
# uric acid                                   0.180985  0.168626   1.000000
# uridine                                     0.051403 -0.093887   0.201183
# valine                                     -0.123681 -0.021021  -0.106261
# xylitol                                     0.797701 -0.091944   0.205345
# xylose                                     -0.049850  0.195460   0.053788
#
#                                   uridine    valine   xylitol    xylose
# 1_5-anhydroglucitol              0.267536 -0.143464  0.286272 -0.086360
# 1-monostearin                   -0.078234 -0.097429 -0.066704 -0.043400
# 2_3-dihydroxybutanoic acid NIST  0.039247  0.024272 -0.067505  0.348359
# 2_4-diaminobutyric acid         -0.103013 -0.104377  0.124099  0.296243
# 2-deoxyerythritol                0.026157 -0.147918 -0.074666  0.328630
# ...                                   ...       ...       ...       ...
# uric acid                        0.201183 -0.106261  0.205345  0.053788
# uridine                          1.000000 -0.145184  0.022417 -0.081399
# valine                          -0.145184  1.000000 -0.128605 -0.162351
# xylitol                          0.022417 -0.128605  1.000000 -0.110091
# xylose                          -0.081399 -0.162351 -0.110091  1.000000
#
# [158 rows x 158 columns]

# %%
from scipy import stats

pearson_p = []
for i in serum.columns:
    if serum[i].dtypes!='O':
        pearson_coef, p_value = stats.pearsonr(serum[i], serum['Class'].map({"control": 0, "disease": 1}))
        pearson_p.append([i, pearson_coef, p_value])
pearson_p_df = pd.DataFrame(pearson_p, columns=['Features', 'Pearson Coefficient', 'p-Value'])
pearson_p_df
# Out:
#                             Features  Pearson Coefficient   p-Value
# 0                1_5-anhydroglucitol            -0.074873  0.503792
# 1                      1-monostearin            -0.047979  0.668620
# 2    2_3-dihydroxybutanoic acid NIST            -0.178369  0.108871
# 3            2_4-diaminobutyric acid            -0.141305  0.205407
# 4                  2-deoxyerythritol             0.017060  0.879089
# ..                               ...                  ...       ...
# 153                        uric acid            -0.278142  0.011401
# 154                          uridine             0.072417  0.517926
# 155                           valine            -0.096290  0.389481
# 156                          xylitol            -0.131320  0.239595
# 157                           xylose             0.008316  0.940890
#
# [158 rows x 3 columns]

# %%
pearson_p_final = []
for i in range(158):
    if pearson_p_df.loc[i, 'p-Value'] < 0.001:
        pearson_p_final.append(pearson_p_df.loc[i, 'Features'])
pearson_p_final
# Out:
# ['aspartic acid', 'phenol', 'taurine']

# %% [markdown]
# ### So important variables we derived:
#
# 'aspartic acid', 'phenol', 'taurine'

# %%
# necessary functions
from sklearn.decomposition import PCA
labels = np.reshape(serum['Class'].to_numpy(), (82,1))

def pca_analysis(df, n_components):
    pca = PCA(n_components=n_components)
    pca_result = pca.fit_transform(df.iloc[:, :-1].values)

    pca_concatenate = np.concatenate([pca_result, labels], axis=1)
    return pca_concatenate

def make_dataframe(array, n_features):
    col = []
    for i in range(1, n_features+1):
        col.append(f'pc{i}')
    col.append('Class')
    return pd.DataFrame(array, columns = col)

from sklearn.manifold import TSNE
def tsne_analysis(df, n_components):
    tsne = TSNE(n_components=n_components)
    tsne_result = tsne.fit_transform(df.iloc[:, :-1].values)

    tsne_concatenate = np.concatenate([tsne_result, labels], axis=1)
    return tsne_concatenate
def tsne_dataframe(array, n_features):
    col = []
    for i in range(1, n_features+1):
        col.append(f'tsne{i}')
    col.append('Class')
    return pd.DataFrame(array, columns = col)

def get_xy(df):
  X = df.drop('Class', axis=1)
  X = X.apply(pd.to_numeric)
  y = df['Class'].copy()
  y = y.map({"control": 0, "disease": 1})
  return X, y

# %% [markdown]
# # Lzypredict

# %%
import lazypredict
from lazypredict.Supervised import LazyClassifier

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import matthews_corrcoef
from sklearn.metrics import classification_report

from sklearn.model_selection import ShuffleSplit, train_test_split, StratifiedKFold
# Out:
# C:\Users\UTSHAB\AppData\Roaming\Python\Python37\site-packages\sklearn\utils\deprecation.py:143: FutureWarning: The sklearn.utils.testing module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.utils. Anything that cannot be imported from sklearn.utils is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
imp0 = ['aspartic acid', 'phenol', 'taurine']

# %%
from sklearn.preprocessing import RobustScaler
scaler = RobustScaler()
accuracy = []
for k in [0, 2, 22]:
    
    if k==0:
        name = ['Serum(Exploratory)_0.001']
        dfs = [serum[imp0]]
    
    elif k==22 or k==23:
        k -= 20
        name = [f'tsne{k}_serum(Exploratory)_0.001']

        vars()[f'tsne{k}_serum'] = pca_analysis(serum[imp0], k)
        vars()[f'tsne{k}_serum_df'] = make_dataframe(vars()[f'tsne{k}_serum'], k)
        
        dfs = [vars()[f'tsne{k}_serum_df']]
    
    else:
        name = [f'pca{k}_serum(Exploratory)_0.001']
        
        vars()[f'pca{k}_serum'] = pca_analysis(serum[imp0], k)
        vars()[f'pca{k}_serum_df'] = make_dataframe(vars()[f'pca{k}_serum'], k)
        
        dfs = [vars()[f'pca{k}_serum_df']]
    
    random_state = 42

    for idx, data in enumerate(dfs):
        result = []
        if data.columns[-1]=='Class':
            X = data.drop('Class', axis=1)
        else:
            X = data
        y = serum['Class'].copy()
        y = y.map({"control": 0, "disease": 1})
        rs = ShuffleSplit(n_splits=10, test_size=.2, random_state=random_state)

        for train_index, test_index in rs.split(X):
            clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=matthews_corrcoef, predictions=True)
            X_train, X_test = X.iloc[train_index], X.iloc[test_index]
            y_train, y_test = y.iloc[train_index], y.iloc[test_index]

            cols = X_train.columns
            X_train = scaler.fit_transform(X_train)
            X_test = scaler.transform(X_test)

            X_train = pd.DataFrame(X_train, columns=[cols])
            X_test = pd.DataFrame(X_test, columns=[cols])

            models, predictions = clf.fit(X_train, X_test, y_train, y_test)
            result.append(models)
        #     print(result)

        acc = []
        for i in range(10):
            acc.append(result[i].iloc[0]['Balanced Accuracy'])

        print(f'\n{name[idx]}: {sum(acc)/len(acc)}')
        accuracy.append([f'{name[idx]}', f'{sum(acc)/len(acc)}'])
# Out:
# 100%|██████████| 29/29 [00:00<00:00, 49.74it/s]
# 100%|██████████| 29/29 [00:00<00:00, 47.77it/s]
# 100%|██████████| 29/29 [00:00<00:00, 45.45it/s]
# 100%|██████████| 29/29 [00:00<00:00, 47.70it/s]
# 100%|██████████| 29/29 [00:00<00:00, 46.33it/s]
# 100%|██████████| 29/29 [00:00<00:00, 47.78it/s]
# 100%|██████████| 29/29 [00:00<00:00, 48.06it/s]
# 100%|██████████| 29/29 [00:00<00:00, 49.32it/s]
# 100%|██████████| 29/29 [00:00<00:00, 49.49it/s]
# 100%|██████████| 29/29 [00:00<00:00, 49.49it/s]
#   7%|▋         | 2/29 [00:00<00:01, 18.87it/s]
# Serum(Exploratory)_0.001: 0.8654186091686091
# 100%|██████████| 29/29 [00:00<00:00, 49.66it/s]
# 100%|██████████| 29/29 [00:00<00:00, 49.83it/s]
# 100%|██████████| 29/29 [00:00<00:00, 45.96it/s]
# 100%|██████████| 29/29 [00:00<00:00, 49.57it/s]
# 100%|██████████| 29/29 [00:00<00:00, 39.24it/s]
# 100%|██████████| 29/29 [00:00<00:00, 49.07it/s]
# 100%|██████████| 29/29 [00:00<00:00, 47.03it/s]
# 100%|██████████| 29/29 [00:00<00:00, 48.58it/s]
# 100%|██████████| 29/29 [00:00<00:00, 48.31it/s]
# 100%|██████████| 29/29 [00:00<00:00, 49.15it/s]
#   7%|▋         | 2/29 [00:00<00:01, 18.52it/s]
# pca2_serum(Exploratory)_0.001: 0.898052641802642
# 100%|██████████| 29/29 [00:00<00:00, 45.38it/s]
# 100%|██████████| 29/29 [00:00<00:00, 48.41it/s]
# 100%|██████████| 29/29 [00:00<00:00, 49.24it/s]
# 100%|██████████| 29/29 [00:00<00:00, 34.09it/s]
# 100%|██████████| 29/29 [00:00<00:00, 44.75it/s]
# 100%|██████████| 29/29 [00:00<00:00, 47.00it/s]
# 100%|██████████| 29/29 [00:00<00:00, 48.90it/s]
# 100%|██████████| 29/29 [00:00<00:00, 48.17it/s]
# 100%|██████████| 29/29 [00:00<00:00, 47.78it/s]
# 100%|██████████| 29/29 [00:00<00:00, 36.99it/s]
# tsne2_serum(Exploratory)_0.001: 0.898052641802642

# %%
accuracy_df = pd.DataFrame(accuracy, columns=['Processed Dataset', 'Accuracy'])
accuracy_df.to_csv('G:/Research/SM Sir/LungCancer_Biomarker/accuracy/accuracy_exploratory_serum2.csv', index=False)
accuracy_df
# Out:
#                 Processed Dataset            Accuracy
# 0        Serum(Exploratory)_0.001  0.8654186091686091
# 1   pca2_serum(Exploratory)_0.001   0.898052641802642
# 2  tsne2_serum(Exploratory)_0.001   0.898052641802642

# %%
path = 'G:/Research/SM Sir/LungCancer_Biomarker/accuracy/'
initial = pd.read_csv(f'{path}accuracy_final.csv').iloc[:, 1:]
meta = pd.read_csv(f'{path}accuracy_Specific Metabolics2.csv')
plas = pd.read_csv(f'{path}accuracy_exploratory_plasma2.csv')
ser = accuracy_df

final = pd.concat([initial, meta, plas, ser], axis=0, ignore_index=True)
final
# Out:
#                  Processed Dataset            Accuracy
# 0              Plasma(Exploratory)                0.89
# 1               Serum(Exploratory)                0.87
# 2         pca2_plasma(Exploratory)                0.82
# 3          pca2_serum(Exploratory)                0.87
# 4         pca3_plasma(Exploratory)                0.84
# ..                             ...                 ...
# 75       tsne2_plasma(Exploratory)                0.79
# 76       tsne3_plasma(Exploratory)                0.76
# 77        Serum(Exploratory)_0.001  0.8654186091686091
# 78   pca2_serum(Exploratory)_0.001   0.898052641802642
# 79  tsne2_serum(Exploratory)_0.001   0.898052641802642
#
# [80 rows x 2 columns]

# %%
final.to_csv(f'{path}accuracy_final.csv')
