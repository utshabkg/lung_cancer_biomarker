# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
plasma = pd.read_csv('dataset/plasma_processed.csv')
serum = pd.read_csv('dataset/serum_processed.csv')
plasma = plasma.drop(['Unnamed: 0'], axis=1)
serum = serum.drop(['Unnamed: 0'], axis=1)
plasma
# Out:
#     1_5-anhydroglucitol  1-monostearin  2_3-dihydroxybutanoic acid NIST  \
# 0                  9483            103                              101
# 1                 27468            207                              155
# 2                 13976             86                               78
# 3                 19449            178                              104
# 4                 17209            258                              103
# ..                  ...            ...                              ...
# 77                25149            184                              154
# 78                24181            142                              135
# 79                23848            118                               65
# 80                13848             97                               65
# 81                19669            187                              177
#
#     2_4-diaminobutyric acid  2-deoxyerythritol  2-deoxytetronic acid  \
# 0                       963                389                   123
# 1                       335                227                   178
# 2                       176                152                    83
# 3                       467                270                   157
# 4                       979                314                   211
# ..                      ...                ...                   ...
# 77                      444                142                   244
# 78                      786                226                   146
# 79                      132                352                   294
# 80                      881                444                   122
# 81                      450                166                   171
#
#     2-hydroxybutanoic acid  2-hydroxyglutaric acid  2-hydroxyhippuric acid  \
# 0                    20744                     139                      36
# 1                     8611                      78                      91
# 2                    22792                      92                      97
# 3                    29418                     123                      92
# 4                    16713                      76                      42
# ..                     ...                     ...                     ...
# 77                   20728                      51                     128
# 78                   10688                      64                      59
# 79                   10077                      42                      56
# 80                   14869                      75                     203
# 81                   14464                      23                     258
#
#     2-hydroxyvaleric acid  ...  tryptophan  tyrosine  UDP-glucuronic acid  \
# 0                     955  ...       27450     52403                   73
# 1                     103  ...       17898     37179                  157
# 2                    1010  ...       29503     30670                  211
# 3                     289  ...       16501     27573                   71
# 4                    1126  ...       24023     30096                  222
# ..                    ...  ...         ...       ...                  ...
# 77                    186  ...       30518     36411                  114
# 78                     80  ...       23731     26506                  110
# 79                    867  ...       30277     35764                  158
# 80                   1104  ...       14930     18921                 2176
# 81                    984  ...       17881     28443                   57
#
#       urea  uric acid  uridine  valine  xylitol  xylose    Class
# 0   255067      10057       63  157332      154    1380  disease
# 1   180080       8386      118  103083      324     929  disease
# 2   138861      15822      119   92045      253     610  disease
# 3   183633      14024      102   97349      223     746  disease
# 4   255081      23154       58  159671      189    2022  disease
# ..     ...        ...      ...     ...      ...     ...      ...
# 77  226793      17880       57  114920      252     856  control
# 78  365044      29018       61  127248      359    1003  control
# 79  327943      19736       76   78152      453    1279  control
# 80  323303      17479      108   96830     1450    1045  control
# 81  190031      32421       79  122408      225    2585  control
#
# [82 rows x 159 columns]

# %%
plasma.dtypes
# Out:
# 1_5-anhydroglucitol                 int64
# 1-monostearin                       int64
# 2_3-dihydroxybutanoic acid NIST     int64
# 2_4-diaminobutyric acid             int64
# 2-deoxyerythritol                   int64
#                                     ...
# uridine                             int64
# valine                              int64
# xylitol                             int64
# xylose                              int64
# Class                              object
# Length: 159, dtype: object

# %% [markdown]
# # Deal with NaN Values:

# %%
plasma.isnull().any()
# Out:
# 1_5-anhydroglucitol                False
# 1-monostearin                      False
# 2_3-dihydroxybutanoic acid NIST    False
# 2_4-diaminobutyric acid            False
# 2-deoxyerythritol                  False
#                                    ...
# uridine                            False
# valine                             False
# xylitol                            False
# xylose                             False
# Class                              False
# Length: 159, dtype: bool

# %%
plasma.corr()
# Out:
#                                  1_5-anhydroglucitol  1-monostearin  \
# 1_5-anhydroglucitol                             1.00          -0.18
# 1-monostearin                                  -0.18           1.00
# 2_3-dihydroxybutanoic acid NIST                -0.02          -0.04
# 2_4-diaminobutyric acid                         0.04          -0.08
# 2-deoxyerythritol                               0.10           0.10
# ...                                              ...            ...
# uric acid                                       0.19          -0.16
# uridine                                         0.20          -0.09
# valine                                         -0.13           0.11
# xylitol                                         0.16          -0.09
# xylose                                         -0.13          -0.05
#
#                                  2_3-dihydroxybutanoic acid NIST  \
# 1_5-anhydroglucitol                                        -0.02
# 1-monostearin                                              -0.04
# 2_3-dihydroxybutanoic acid NIST                             1.00
# 2_4-diaminobutyric acid                                     0.21
# 2-deoxyerythritol                                           0.18
# ...                                                          ...
# uric acid                                                   0.04
# uridine                                                     0.21
# valine                                                      0.02
# xylitol                                                    -0.11
# xylose                                                      0.37
#
#                                  2_4-diaminobutyric acid  2-deoxyerythritol  \
# 1_5-anhydroglucitol                                 0.04               0.10
# 1-monostearin                                      -0.08               0.10
# 2_3-dihydroxybutanoic acid NIST                     0.21               0.18
# 2_4-diaminobutyric acid                             1.00               0.19
# 2-deoxyerythritol                                   0.19               1.00
# ...                                                  ...                ...
# uric acid                                           0.07               0.10
# uridine                                             0.05               0.23
# valine                                              0.18              -0.23
# xylitol                                             0.25              -0.03
# xylose                                              0.15               0.31
#
#                                  2-deoxytetronic acid  2-hydroxybutanoic acid  \
# 1_5-anhydroglucitol                              0.07                   -0.16
# 1-monostearin                                   -0.20                   -0.12
# 2_3-dihydroxybutanoic acid NIST                  0.35                   -0.06
# 2_4-diaminobutyric acid                          0.27                   -0.15
# 2-deoxyerythritol                                0.23                   -0.31
# ...                                               ...                     ...
# uric acid                                        0.12                   -0.13
# uridine                                         -0.04                   -0.14
# valine                                          -0.46                    0.12
# xylitol                                          0.12                   -0.25
# xylose                                           0.36                   -0.25
#
#                                  2-hydroxyglutaric acid  \
# 1_5-anhydroglucitol                               -0.00
# 1-monostearin                                      0.04
# 2_3-dihydroxybutanoic acid NIST                    0.08
# 2_4-diaminobutyric acid                            0.06
# 2-deoxyerythritol                                  0.07
# ...                                                 ...
# uric acid                                         -0.17
# uridine                                            0.13
# valine                                             0.14
# xylitol                                           -0.05
# xylose                                            -0.05
#
#                                  2-hydroxyhippuric acid  \
# 1_5-anhydroglucitol                               -0.23
# 1-monostearin                                      0.57
# 2_3-dihydroxybutanoic acid NIST                   -0.01
# 2_4-diaminobutyric acid                           -0.03
# 2-deoxyerythritol                                  0.10
# ...                                                 ...
# uric acid                                         -0.01
# uridine                                           -0.13
# valine                                            -0.08
# xylitol                                           -0.01
# xylose                                            -0.03
#
#                                  2-hydroxyvaleric acid  ...  \
# 1_5-anhydroglucitol                              -0.14  ...
# 1-monostearin                                     0.05  ...
# 2_3-dihydroxybutanoic acid NIST                   0.17  ...
# 2_4-diaminobutyric acid                          -0.03  ...
# 2-deoxyerythritol                                 0.17  ...
# ...                                                ...  ...
# uric acid                                         0.05  ...
# uridine                                           0.06  ...
# valine                                           -0.01  ...
# xylitol                                          -0.16  ...
# xylose                                            0.33  ...
#
#                                  trans-4-hydroxyproline  tryptophan  tyrosine  \
# 1_5-anhydroglucitol                               -0.00        0.16      0.07
# 1-monostearin                                      0.04       -0.03      0.10
# 2_3-dihydroxybutanoic acid NIST                    0.07       -0.14     -0.09
# 2_4-diaminobutyric acid                            0.00       -0.19      0.12
# 2-deoxyerythritol                                  0.21        0.02      0.18
# ...                                                 ...         ...       ...
# uric acid                                          0.33        0.01     -0.19
# uridine                                            0.09        0.08     -0.05
# valine                                             0.01        0.23      0.35
# xylitol                                           -0.06       -0.18     -0.07
# xylose                                             0.25       -0.33     -0.11
#
#                                  UDP-glucuronic acid  urea  uric acid  \
# 1_5-anhydroglucitol                            -0.05 -0.28       0.19
# 1-monostearin                                  -0.07  0.07      -0.16
# 2_3-dihydroxybutanoic acid NIST                -0.08  0.16       0.04
# 2_4-diaminobutyric acid                         0.25  0.12       0.07
# 2-deoxyerythritol                              -0.06  0.14       0.10
# ...                                              ...   ...        ...
# uric acid                                       0.17  0.03       1.00
# uridine                                         0.13 -0.18       0.09
# valine                                         -0.11 -0.03      -0.10
# xylitol                                         0.77  0.13       0.19
# xylose                                         -0.01  0.28       0.16
#
#                                  uridine  valine  xylitol  xylose
# 1_5-anhydroglucitol                 0.20   -0.13     0.16   -0.13
# 1-monostearin                      -0.09    0.11    -0.09   -0.05
# 2_3-dihydroxybutanoic acid NIST     0.21    0.02    -0.11    0.37
# 2_4-diaminobutyric acid             0.05    0.18     0.25    0.15
# 2-deoxyerythritol                   0.23   -0.23    -0.03    0.31
# ...                                  ...     ...      ...     ...
# uric acid                           0.09   -0.10     0.19    0.16
# uridine                             1.00   -0.26     0.10    0.17
# valine                             -0.26    1.00    -0.16    0.01
# xylitol                             0.10   -0.16     1.00   -0.08
# xylose                              0.17    0.01    -0.08    1.00
#
# [158 rows x 158 columns]

# %%
from scipy import stats

pearson_p = []
for i in plasma.columns:
    if plasma[i].dtypes!='O':
        pearson_coef, p_value = stats.pearsonr(plasma[i], plasma['Class'].map({"control": 0, "disease": 1}))
        pearson_p.append([i, pearson_coef, p_value])
pearson_p_df = pd.DataFrame(pearson_p, columns=['Features', 'Pearson Coefficient', 'p-Value'])
pearson_p_df
# Out:
#                             Features  Pearson Coefficient  p-Value
# 0                1_5-anhydroglucitol                -0.05     0.65
# 1                      1-monostearin                 0.18     0.11
# 2    2_3-dihydroxybutanoic acid NIST                 0.08     0.49
# 3            2_4-diaminobutyric acid                 0.08     0.50
# 4                  2-deoxyerythritol                 0.06     0.59
# ..                               ...                  ...      ...
# 153                        uric acid                -0.31     0.00
# 154                          uridine                -0.00     0.99
# 155                           valine                -0.09     0.40
# 156                          xylitol                -0.07     0.54
# 157                           xylose                 0.05     0.67
#
# [158 rows x 3 columns]

# %%
pearson_p_final = []
for i in range(158):
    if pearson_p_df.loc[i, 'p-Value'] < 0.001:
        pearson_p_final.append(pearson_p_df.loc[i, 'Features'])
pearson_p_final
# Out:
# ['3-phosphoglycerate',
#  '5-methoxytryptamine',
#  'adenosine-5-monophosphate',
#  'asparagine',
#  'aspartic acid',
#  'lactic acid',
#  'phenol',
#  'pyrophosphate',
#  'pyruvic acid',
#  'taurine']

# %% [markdown]
# ### So important variables we derived:
#
# '3-phosphoglycerate',
#  '5-methoxytryptamine',
#  'adenosine-5-monophosphate',
#  'asparagine',
#  'aspartic acid',
#  'lactic acid',
#  'phenol',
#  'pyrophosphate',
#  'pyruvic acid',
#  'taurine'

# %%
# necessary functions
from sklearn.decomposition import PCA
labels = np.reshape(plasma['Class'].to_numpy(), (82,1))

def pca_analysis(df, n_components):
    pca = PCA(n_components=n_components)
    pca_result = pca.fit_transform(df.iloc[:, :-1].values)

    pca_concatenate = np.concatenate([pca_result, labels], axis=1)
    return pca_concatenate

def make_dataframe(array, n_features):
    col = []
    for i in range(1, n_features+1):
        col.append(f'pc{i}')
    col.append('Class')
    return pd.DataFrame(array, columns = col)

from sklearn.manifold import TSNE
def tsne_analysis(df, n_components):
    tsne = TSNE(n_components=n_components)
    tsne_result = tsne.fit_transform(df.iloc[:, :-1].values)

    tsne_concatenate = np.concatenate([tsne_result, labels], axis=1)
    return tsne_concatenate
def tsne_dataframe(array, n_features):
    col = []
    for i in range(1, n_features+1):
        col.append(f'tsne{i}')
    col.append('Class')
    return pd.DataFrame(array, columns = col)

def get_xy(df):
  X = df.drop('Class', axis=1)
  X = X.apply(pd.to_numeric)
  y = df['Class'].copy()
  y = y.map({"control": 0, "disease": 1})
  return X, y

# %% [markdown]
# # Lzypredict

# %%
import lazypredict
from lazypredict.Supervised import LazyClassifier

from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import matthews_corrcoef
from sklearn.metrics import classification_report

from sklearn.model_selection import ShuffleSplit, train_test_split, StratifiedKFold

# %%
imp0 = ['3-phosphoglycerate',
 '5-methoxytryptamine',
 'adenosine-5-monophosphate',
 'asparagine',
 'aspartic acid',
 'lactic acid',
 'phenol',
 'pyrophosphate',
 'pyruvic acid',
 'taurine']

# %%
accuracy = []
for k in [0, 2, 3, 4, 5, 22, 23]:
    
    if k==0:
        name = ['Plasma(Exploratory)', 'Serum(Exploratory)']
        dfs = [plasma[imp0], serum[imp0]]
    
    elif k==22 or k==23:
        k -= 20
        name = [f'tsne{k}_plasma(Exploratory)', f'tsne{k}_serum(Exploratory)']
        vars()[f'tsne{k}_plasma'] = tsne_analysis(plasma[imp0], k)
        vars()[f'tsne{k}_plasma_df'] = make_dataframe(vars()[f'tsne{k}_plasma'], k)
        
        vars()[f'tsne{k}_serum'] = pca_analysis(serum[imp0], k)
        vars()[f'tsne{k}_serum_df'] = make_dataframe(vars()[f'tsne{k}_serum'], k)
        
        dfs = [vars()[f'tsne{k}_plasma_df'], vars()[f'tsne{k}_serum_df']]
    
    else:
        name = [f'pca{k}_plasma(Exploratory)', f'pca{k}_serum(Exploratory)']
        vars()[f'pca{k}_plasma'] = pca_analysis(plasma[imp0], k)
        vars()[f'pca{k}_plasma_df'] = make_dataframe(vars()[f'pca{k}_plasma'], k)
        
        vars()[f'pca{k}_serum'] = pca_analysis(serum[imp0], k)
        vars()[f'pca{k}_serum_df'] = make_dataframe(vars()[f'pca{k}_serum'], k)
        
        dfs = [vars()[f'pca{k}_plasma_df'], vars()[f'pca{k}_serum_df']]
    
    random_state = 42

    for idx, data in enumerate(dfs):
        result = []
        if data.columns[-1]=='Class':
            X = data.drop('Class', axis=1)
        else:
            X = data
        y = plasma['Class'].copy()
        y = y.map({"control": 0, "disease": 1})
        rs = ShuffleSplit(n_splits=10, test_size=.2, random_state=random_state)

        for train_index, test_index in rs.split(X):
            clf = LazyClassifier(verbose=0, ignore_warnings=True, custom_metric=matthews_corrcoef, predictions=True)
            X_train, X_test = X.iloc[train_index], X.iloc[test_index]
            y_train, y_test = y.iloc[train_index], y.iloc[test_index]

            scaler = RobustScaler()

            cols = X_train.columns
            X_train = scaler.fit_transform(X_train)
            X_test = scaler.transform(X_test)

            X_train = pd.DataFrame(X_train, columns=[cols])
            X_test = pd.DataFrame(X_test, columns=[cols])

            models, predictions = clf.fit(X_train, X_test, y_train, y_test)
            result.append(models)
        #     print(result)

        acc = []
        for i in range(10):
            acc.append(result[i].iloc[0]['Balanced Accuracy'])

        print(f'\n{name[idx]}: {sum(acc)/len(acc)}')
        accuracy.append([f'{name[idx]}', f'{sum(acc)/len(acc)}'])
# Out:
# 100%|██████████| 29/29 [00:00<00:00, 44.82it/s]
# 100%|██████████| 29/29 [00:00<00:00, 44.96it/s]
# 100%|██████████| 29/29 [00:00<00:00, 45.24it/s]
# 100%|██████████| 29/29 [00:00<00:00, 47.62it/s]
# 100%|██████████| 29/29 [00:00<00:00, 47.93it/s]
# 100%|██████████| 29/29 [00:00<00:00, 47.26it/s]
# 100%|██████████| 29/29 [00:00<00:00, 46.32it/s]
# 100%|██████████| 29/29 [00:00<00:00, 47.15it/s]
# 100%|██████████| 29/29 [00:00<00:00, 41.97it/s]
# 100%|██████████| 29/29 [00:00<00:00, 46.33it/s]
#   7%|▋         | 2/29 [00:00<00:01, 17.70it/s]
# Plasma(Exploratory): 0.890166083916084
# 100%|██████████| 29/29 [00:00<00:00, 45.67it/s]
# 100%|██████████| 29/29 [00:00<00:00, 42.90it/s]
# 100%|██████████| 29/29 [00:00<00:00, 34.73it/s]
# 100%|██████████| 29/29 [00:00<00:00, 44.98it/s]
# 100%|██████████| 29/29 [00:00<00:00, 46.33it/s]
# 100%|██████████| 29/29 [00:00<00:00, 46.40it/s]
# 100%|██████████| 29/29 [00:00<00:00, 44.55it/s]
# 100%|██████████| 29/29 [00:00<00:00, 44.41it/s]
# 100%|██████████| 29/29 [00:00<00:00, 44.04it/s]
# 100%|██████████| 29/29 [00:00<00:00, 42.90it/s]
#   7%|▋         | 2/29 [00:00<00:01, 18.52it/s]
# Serum(Exploratory): 0.8702845765345766
# 100%|██████████| 29/29 [00:00<00:00, 47.54it/s]
# 100%|██████████| 29/29 [00:00<00:00, 42.58it/s]
# 100%|██████████| 29/29 [00:00<00:00, 44.75it/s]
# 100%|██████████| 29/29 [00:00<00:00, 44.96it/s]
# 100%|██████████| 29/29 [00:00<00:00, 48.90it/s]
# 100%|██████████| 29/29 [00:00<00:00, 47.85it/s]
# 100%|██████████| 29/29 [00:00<00:00, 47.93it/s]
# 100%|██████████| 29/29 [00:00<00:00, 45.89it/s]
# 100%|██████████| 29/29 [00:00<00:00, 46.10it/s]
# 100%|██████████| 29/29 [00:00<00:00, 48.03it/s]
#   7%|▋         | 2/29 [00:00<00:01, 18.18it/s]
# pca2_plasma(Exploratory): 0.8197163947163947
# 100%|██████████| 29/29 [00:00<00:00, 47.31it/s]
# 100%|██████████| 29/29 [00:00<00:00, 48.50it/s]
# 100%|██████████| 29/29 [00:00<00:00, 48.74it/s]
# 100%|██████████| 29/29 [00:00<00:00, 47.78it/s]
# 100%|██████████| 29/29 [00:00<00:00, 48.66it/s]
# 100%|██████████| 29/29 [00:00<00:00, 39.35it/s]
# 100%|██████████| 29/29 [00:00<00:00, 47.39it/s]
# 100%|██████████| 29/29 [00:00<00:00, 38.51it/s]
# 100%|██████████| 29/29 [00:00<00:00, 34.98it/s]
# 100%|██████████| 29/29 [00:00<00:00, 33.92it/s]
#   7%|▋         | 2/29 [00:00<00:01, 16.53it/s]
# pca2_serum(Exploratory): 0.8668706293706292
# 100%|██████████| 29/29 [00:00<00:00, 42.15it/s]
# 100%|██████████| 29/29 [00:00<00:00, 37.71it/s]
# 100%|██████████| 29/29 [00:00<00:00, 40.17it/s]
# 100%|██████████| 29/29 [00:00<00:00, 46.57it/s]
# 100%|██████████| 29/29 [00:00<00:00, 47.54it/s]
# 100%|██████████| 29/29 [00:00<00:00, 49.91it/s]
# 100%|██████████| 29/29 [00:00<00:00, 48.90it/s]
# 100%|██████████| 29/29 [00:00<00:00, 50.17it/s]
# 100%|██████████| 29/29 [00:00<00:00, 50.00it/s]
# 100%|██████████| 29/29 [00:00<00:00, 49.15it/s]
#   7%|▋         | 2/29 [00:00<00:01, 18.52it/s]
# pca3_plasma(Exploratory): 0.8393550893550893
# 100%|██████████| 29/29 [00:00<00:00, 49.07it/s]
# 100%|██████████| 29/29 [00:00<00:00, 49.57it/s]
# 100%|██████████| 29/29 [00:00<00:00, 49.40it/s]
# 100%|██████████| 29/29 [00:00<00:00, 48.66it/s]
# 100%|██████████| 29/29 [00:00<00:00, 39.51it/s]
# 100%|██████████| 29/29 [00:00<00:00, 45.89it/s]
# 100%|██████████| 29/29 [00:00<00:00, 47.62it/s]
# 100%|██████████| 29/29 [00:00<00:00, 37.96it/s]
# 100%|██████████| 29/29 [00:01<00:00, 28.83it/s]
# 100%|██████████| 29/29 [00:00<00:00, 38.21it/s]
#   7%|▋         | 2/29 [00:00<00:01, 17.39it/s]
# pca3_serum(Exploratory): 0.8817162004662006
# 100%|██████████| 29/29 [00:00<00:00, 48.01it/s]
# 100%|██████████| 29/29 [00:00<00:00, 48.66it/s]
# 100%|██████████| 29/29 [00:00<00:00, 47.22it/s]
# 100%|██████████| 29/29 [00:00<00:00, 48.09it/s]
# 100%|██████████| 29/29 [00:00<00:00, 46.21it/s]
# 100%|██████████| 29/29 [00:00<00:00, 49.83it/s]
# 100%|██████████| 29/29 [00:00<00:00, 37.08it/s]
# 100%|██████████| 29/29 [00:00<00:00, 37.61it/s]
# 100%|██████████| 29/29 [00:00<00:00, 46.18it/s]
# 100%|██████████| 29/29 [00:00<00:00, 46.18it/s]
#   3%|▎         | 1/29 [00:00<00:03,  9.26it/s]
# pca4_plasma(Exploratory): 0.8244405594405594
# 100%|██████████| 29/29 [00:00<00:00, 31.76it/s]
# 100%|██████████| 29/29 [00:00<00:00, 45.81it/s]
# 100%|██████████| 29/29 [00:00<00:00, 46.93it/s]
# 100%|██████████| 29/29 [00:00<00:00, 47.15it/s]
# 100%|██████████| 29/29 [00:00<00:00, 43.28it/s]
# 100%|██████████| 29/29 [00:00<00:00, 46.70it/s]
# 100%|██████████| 29/29 [00:00<00:00, 46.10it/s]
# 100%|██████████| 29/29 [00:00<00:00, 48.25it/s]
# 100%|██████████| 29/29 [00:00<00:00, 38.41it/s]
# 100%|██████████| 29/29 [00:00<00:00, 46.10it/s]
#   7%|▋         | 2/29 [00:00<00:01, 18.52it/s]
# pca4_serum(Exploratory): 0.8710372960372961
# 100%|██████████| 29/29 [00:00<00:00, 47.46it/s]
# 100%|██████████| 29/29 [00:00<00:00, 48.17it/s]
# 100%|██████████| 29/29 [00:00<00:00, 48.74it/s]
# 100%|██████████| 29/29 [00:00<00:00, 47.23it/s]
# 100%|██████████| 29/29 [00:00<00:00, 44.96it/s]
# 100%|██████████| 29/29 [00:00<00:00, 47.85it/s]
# 100%|██████████| 29/29 [00:00<00:00, 47.15it/s]
# 100%|██████████| 29/29 [00:00<00:00, 48.09it/s]
# 100%|██████████| 29/29 [00:00<00:00, 46.93it/s]
# 100%|██████████| 29/29 [00:00<00:00, 44.62it/s]
#   7%|▋         | 2/29 [00:00<00:01, 17.24it/s]
# pca5_plasma(Exploratory): 0.8438422688422689
# 100%|██████████| 29/29 [00:00<00:00, 45.03it/s]
# 100%|██████████| 29/29 [00:00<00:00, 47.31it/s]
# 100%|██████████| 29/29 [00:00<00:00, 48.58it/s]
# 100%|██████████| 29/29 [00:00<00:00, 48.25it/s]
# 100%|██████████| 29/29 [00:00<00:00, 48.17it/s]
# 100%|██████████| 29/29 [00:00<00:00, 46.70it/s]
# 100%|██████████| 29/29 [00:00<00:00, 45.45it/s]
# 100%|██████████| 29/29 [00:00<00:00, 47.90it/s]
# 100%|██████████| 29/29 [00:00<00:00, 47.54it/s]
# 100%|██████████| 29/29 [00:00<00:00, 47.78it/s]
# pca5_serum(Exploratory): 0.8675019425019425
# 100%|██████████| 29/29 [00:00<00:00, 47.54it/s]
# 100%|██████████| 29/29 [00:00<00:00, 47.00it/s]
# 100%|██████████| 29/29 [00:00<00:00, 48.50it/s]
# 100%|██████████| 29/29 [00:00<00:00, 45.19it/s]
# 100%|██████████| 29/29 [00:00<00:00, 40.79it/s]
# 100%|██████████| 29/29 [00:00<00:00, 47.54it/s]
# 100%|██████████| 29/29 [00:00<00:00, 48.33it/s]
# 100%|██████████| 29/29 [00:00<00:00, 48.90it/s]
# 100%|██████████| 29/29 [00:00<00:00, 47.78it/s]
# 100%|██████████| 29/29 [00:00<00:00, 46.10it/s]
#   7%|▋         | 2/29 [00:00<00:01, 18.35it/s]
# tsne2_plasma(Exploratory): 0.833448912198912
# 100%|██████████| 29/29 [00:00<00:00, 48.82it/s]
# 100%|██████████| 29/29 [00:00<00:00, 47.70it/s]
# 100%|██████████| 29/29 [00:00<00:00, 47.85it/s]
# 100%|██████████| 29/29 [00:00<00:00, 45.60it/s]
# 100%|██████████| 29/29 [00:00<00:00, 48.49it/s]
# 100%|██████████| 29/29 [00:00<00:00, 48.74it/s]
# 100%|██████████| 29/29 [00:00<00:00, 48.82it/s]
# 100%|██████████| 29/29 [00:00<00:00, 46.93it/s]
# 100%|██████████| 29/29 [00:00<00:00, 48.66it/s]
# 100%|██████████| 29/29 [00:00<00:00, 47.93it/s]
# tsne2_serum(Exploratory): 0.8668706293706292
# 100%|██████████| 29/29 [00:00<00:00, 47.85it/s]
# 100%|██████████| 29/29 [00:00<00:00, 47.93it/s]
# 100%|██████████| 29/29 [00:00<00:00, 48.09it/s]
# 100%|██████████| 29/29 [00:00<00:00, 48.41it/s]
# 100%|██████████| 29/29 [00:00<00:00, 48.33it/s]
# 100%|██████████| 29/29 [00:00<00:00, 47.78it/s]
# 100%|██████████| 29/29 [00:00<00:00, 47.31it/s]
# 100%|██████████| 29/29 [00:00<00:00, 48.33it/s]
# 100%|██████████| 29/29 [00:00<00:00, 46.77it/s]
# 100%|██████████| 29/29 [00:00<00:00, 43.15it/s]
#   7%|▋         | 2/29 [00:00<00:01, 18.18it/s]
# tsne3_plasma(Exploratory): 0.7701000388500387
# 100%|██████████| 29/29 [00:00<00:00, 48.90it/s]
# 100%|██████████| 29/29 [00:00<00:00, 48.58it/s]
# 100%|██████████| 29/29 [00:00<00:00, 48.74it/s]
# 100%|██████████| 29/29 [00:00<00:00, 48.49it/s]
# 100%|██████████| 29/29 [00:00<00:00, 48.41it/s]
# 100%|██████████| 29/29 [00:00<00:00, 47.85it/s]
# 100%|██████████| 29/29 [00:00<00:00, 46.47it/s]
# 100%|██████████| 29/29 [00:00<00:00, 46.70it/s]
# 100%|██████████| 29/29 [00:00<00:00, 47.62it/s]
# 100%|██████████| 29/29 [00:00<00:00, 46.25it/s]
# tsne3_serum(Exploratory): 0.8817162004662006

# %%
accuracy_df = pd.DataFrame(accuracy, columns=['Processed Dataset', 'Accuracy'])
accuracy_df.to_csv('accuracy/accuracy_exploratory.csv', index=False)
accuracy_df
# Out:
#             Processed Dataset            Accuracy
# 0         Plasma(Exploratory)   0.890166083916084
# 1          Serum(Exploratory)  0.8702845765345766
# 2    pca2_plasma(Exploratory)  0.8197163947163947
# 3     pca2_serum(Exploratory)  0.8668706293706292
# 4    pca3_plasma(Exploratory)  0.8393550893550893
# 5     pca3_serum(Exploratory)  0.8817162004662006
# 6    pca4_plasma(Exploratory)  0.8244405594405594
# 7     pca4_serum(Exploratory)  0.8710372960372961
# 8    pca5_plasma(Exploratory)  0.8438422688422689
# 9     pca5_serum(Exploratory)  0.8675019425019425
# 10  tsne2_plasma(Exploratory)   0.833448912198912
# 11   tsne2_serum(Exploratory)  0.8668706293706292
# 12  tsne3_plasma(Exploratory)  0.7701000388500387
# 13   tsne3_serum(Exploratory)  0.8817162004662006

# %%
final_acc = pd.concat([accuracy_df, pd.read_csv('accuracy/accuracy_Raw.csv'),\
                       pd.read_csv('accuracy/accuracy_Specific Metabolics.csv')], ignore_index=True)
final_acc.to_csv('accuracy/accuracy_final.csv')
final_acc
# Out:
#                     Processed Dataset            Accuracy  Unnamed: 0
# 0                 Plasma(Exploratory)   0.890166083916084         nan
# 1                  Serum(Exploratory)  0.8702845765345766         nan
# 2            pca2_plasma(Exploratory)  0.8197163947163947         nan
# 3             pca2_serum(Exploratory)  0.8668706293706292         nan
# 4            pca3_plasma(Exploratory)  0.8393550893550893         nan
# 5             pca3_serum(Exploratory)  0.8817162004662006         nan
# 6            pca4_plasma(Exploratory)  0.8244405594405594         nan
# 7             pca4_serum(Exploratory)  0.8710372960372961         nan
# 8            pca5_plasma(Exploratory)  0.8438422688422689         nan
# 9             pca5_serum(Exploratory)  0.8675019425019425         nan
# 10          tsne2_plasma(Exploratory)   0.833448912198912         nan
# 11           tsne2_serum(Exploratory)  0.8668706293706292         nan
# 12          tsne3_plasma(Exploratory)  0.7701000388500387         nan
# 13           tsne3_serum(Exploratory)  0.8817162004662006         nan
# 14                        Plasma(Raw)                0.87        0.00
# 15                         Serum(Raw)                0.85        1.00
# 16                        pca2_plasma                0.80        2.00
# 17                         pca2_serum                0.70        3.00
# 18                        pca3_plasma                0.83        4.00
# 19                         pca3_serum                0.78        5.00
# 20                        pca4_plasma                0.86        6.00
# 21                         pca4_serum                0.83        7.00
# 22                        pca5_plasma                0.83        8.00
# 23                         pca5_serum                0.83        9.00
# 24                       pca10_plasma                0.84       10.00
# 25                        pca10_serum                0.82       11.00
# 26                       pca15_plasma                0.85       12.00
# 27                        pca15_serum                0.81       13.00
# 28                       pca20_plasma                0.83       14.00
# 29                        pca20_serum                0.84       15.00
# 30                       tsne2_plasma                0.78       16.00
# 31                        tsne2_serum                0.77       17.00
# 32                       tsne3_plasma                0.77       18.00
# 33                        tsne3_serum                0.72       19.00
# 34        Plasma(Specific Metabolics)                0.88        0.00
# 35         Serum(Specific Metabolics)                0.93        1.00
# 36   pca2_plasma(Specific Metabolics)                0.90        2.00
# 37    pca2_serum(Specific Metabolics)                0.89        3.00
# 38   pca3_plasma(Specific Metabolics)                0.89        4.00
# 39    pca3_serum(Specific Metabolics)                0.88        5.00
# 40   pca4_plasma(Specific Metabolics)                0.90        6.00
# 41    pca4_serum(Specific Metabolics)                0.88        7.00
# 42   pca5_plasma(Specific Metabolics)                0.90        8.00
# 43    pca5_serum(Specific Metabolics)                0.90        9.00
# 44  pca10_plasma(Specific Metabolics)                0.90       10.00
# 45   pca10_serum(Specific Metabolics)                0.90       11.00
# 46  pca15_plasma(Specific Metabolics)                0.90       12.00
# 47   pca15_serum(Specific Metabolics)                0.90       13.00
# 48  pca20_plasma(Specific Metabolics)                0.88       14.00
# 49   pca20_serum(Specific Metabolics)                0.90       15.00
# 50  tsne2_plasma(Specific Metabolics)                0.91       16.00
# 51   tsne2_serum(Specific Metabolics)                0.89       17.00
# 52  tsne3_plasma(Specific Metabolics)                0.76       18.00
# 53   tsne3_serum(Specific Metabolics)                0.73       19.00
